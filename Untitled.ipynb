# %%
import numpy as np
import  matplotlib.pyplot as plt

# %matplotlib inline

N = 100                                                                          
D = 2

X = np.random.randn(N,D)

X[:50,:] = X[:50,:] - 2*np.ones((50,D))
X[50:,:] = X[50:,:] + 2*np.ones((50,D))

T = np.array([0]*50 + [1]*50)

ones = np.array([[1]*N]).T

Xb = np.concatenate((ones, X), axis = 1)

w = np.random.randn(D + 1)
z = Xb.dot(w)

def sigmoid(z):
    return 1/(1+np.exp(-z))

Y = sigmoid(z)

def cross_entropy(T,Y):
    E = 0
    for i in range(N):
        if T[i] == 1:
            E -= np.log(Y[i])
        else:
            E -= np.log(1 - Y[i])
    return E

learning_rate = 0.1

for i in range(N):
    if i % 10 == 0:
        print(cross_entropy(T,Y))
        print(w)
        #x_axis = np.linspace(-6,6,100)
        #y_axis = - w[2]/w[1]*x_axis - w[0]/w[1]
        #plt.plot(x_axis, y_axis)
    w += learning_rate * np.dot((T-Y).T,Xb)
    Y = sigmoid(Xb.dot(w))

plt.scatter(X[:,0],X[:,1],c = T, s = 100, alpha= 0.7) 
x_axis = np.linspace(-6,6,100)
#y_axis = - w[2]/w[1]*x_axis + w[0]/w[1]
y_axis = - w[1]/w[2]*x_axis - w[0]/w[2]
plt.plot(x_axis, y_axis)
plt.show
# Out:
# 4.604407637298882
# [0.46173495 1.25186063 0.60152862]
# 0.5493695199587089
# [0.05347327 2.14563233 1.88269134]
# 0.3907684805764399
# [-0.12574582  2.35809205  2.1695988 ]
# 0.3113437102675956
# [-0.26220798  2.50394738  2.36989928]
# 0.26140235451160054
# [-0.37336525  2.61730188  2.52822938]
# 0.22641930182529763
# [-0.46732089  2.71087181  2.66091189]
# 0.20028356962510765
# [-0.54871599  2.79094938  2.77595004]
# 0.17989282642480786
# [-0.62050802  2.86115831  2.87794199]
# 0.16347685963867842
# [-0.68471217  2.92379636  2.96980966]
# 0.14994094254994067
# [-0.74276795  2.98042128  3.0535441 ]
# <function matplotlib.pyplot.show>

# %%
import numpy as np
import  matplotlib.pyplot as plt

# %matplotlib inline

N = 400                                                                          
D = 2

"""
X = np.random.randn(N,D)

X[:50,:] = X[:50,:] - 2*np.ones((50,D))
X[50:,:] = X[50:,:] + 2*np.ones((50,D))

T = np.array([0]*50 + [1]*50)

ones = np.array([[1]*N]).T
"""

#np.random.seed(0)

C1 = np.array([[0., -0.8], [1.5, 0.8]])
C2 = np.array([[1., -0.7], [2., 0.7]])
gauss1 = np.dot(np.random.randn(200, 2) + np.array([5, 3]), C1)
gauss2 = np.dot(np.random.randn(200, 2) + np.array([1.5, 0]), C2)

X = np.vstack([gauss1, gauss2])
T = np.array([[0] * 200 + [1] * 200])

ones = np.array([[1]*N]).T
Xb = np.concatenate((ones, X), axis = 1)

w = np.random.randn(D + 1)
z = Xb.dot(w)

def sigmoid(z):
    return 1/(1+np.exp(-z))

Y = sigmoid(z)

def cross_entropy(T,Y):
    E = 0
    for i in range(N):
        if T[i] == 1:
            E -= np.log(Y[i])
        else:
            E -= np.log(1 - Y[i])
    return E

learning_rate = 0.001

for i in range(100):
    if i % 10 == 0:
        #print(cross_entropy(T,Y))
        print(w)
        #x_axis = np.linspace(-6,6,100)
        #y_axis = -w[0]/w[2]*x_axis + w[1]/w[2]
        #plt.plot(x_axis, y_axis)
    w += learning_rate * ((T[0]-Y).T.dot(Xb))

    Y = sigmoid(Xb.dot(w))

plt.scatter(X[:,0],X[:,1],c = T[0], s = 50, alpha= 0.7) 
x_axis = np.linspace(-2,8,10)
y_axis =  -w[1]/w[2]*x_axis - w[0]/w[2]
plt.plot(x_axis, y_axis)
plt.show
# Out:
# [-0.78637737 -1.05985982  1.43499764]
# [ 0.29435738 -0.18757689  0.24453965]
# [ 0.76413637 -0.32362089  0.15849199]
# [ 1.12510035 -0.3862271   0.22983993]
# [ 1.42989128 -0.43396261  0.30747147]
# [ 1.69398757 -0.47540777  0.3758331 ]
# [ 1.92618823 -0.51240905  0.43510648]
# [ 2.13266731 -0.54578     0.48695902]
# [ 2.31801195 -0.5760835   0.53282671]
# [ 2.48571872 -0.60376191  0.57380681]
# <function matplotlib.pyplot.show>

# %%
import numpy as np
import  matplotlib.pyplot as plt

# %matplotlib inline

N = 400                                                                          
D = 2

"""
X = np.random.randn(N,D)

X[:50,:] = X[:50,:] - 2*np.ones((50,D))
X[50:,:] = X[50:,:] + 2*np.ones((50,D))

T = np.array([0]*50 + [1]*50)

ones = np.array([[1]*N]).T
"""

np.random.seed(0)

C1 = np.array([[0., -0.8], [1.5, 0.8]])
C2 = np.array([[1., -0.7], [2., 0.7]])
gauss1 = np.dot(np.random.randn(200, 2) + np.array([5, 3]), C1)
gauss2 = np.dot(np.random.randn(200, 2) + np.array([1.5, 0]), C2)

X = np.vstack([gauss1, gauss2])
#print(X[:7])
T = np.array([[0] * 200 + [1] * 200])

ones = np.array([[1]*N]).T
Xb = np.concatenate((ones, X), axis = 1)

Xb = np.concatenate((Xb,T.T),axis = 1)
#print(Xb.shape, Xb[:5])
w = np.random.randn(D + 1)
#z = Xb.dot(w)

def sigmoid(z):
    return 1/(1+np.exp(-z))

Y = sigmoid(z)

def cross_entropy(T,Y):
    E = 0
    for i in range(N):
        if T[i] == 1:
            E -= np.log(Y[i])
        else:
            E -= np.log(1 - Y[i])
    return E

learning_rate = 0.01

for i in range(100):
    np.random.shuffle(Xb)
    for x in Xb:
        Y = sigmoid(x[:3].dot(w))
        #if i % 10 == 0:
        #print(cross_entropy(T,Y))
        #x_axis = np.linspace(-6,6,100)
        #y_axis = - w[2]/w[1]*x_axis - w[0]/w[1]
        #plt.plot(x_axis, y_axis)
        w += learning_rate * (np.dot(x[3]-Y,(x[:3]))-0.05*w+0.4*np.sign(w))
        #Y = sigmoid(x[:3].dot(w))

print(w)
plt.scatter(X[:,0],X[:,1],c = T[0], s = 50, alpha= 0.7) 
x_axis = np.linspace(-2,8,10)
y_axis =  -w[1]/w[2]*x_axis - w[0]/w[2]
plt.plot(x_axis, y_axis)
plt.show
# Out:
# [ 10.1935537   -2.11177885   3.95999631]
# <function matplotlib.pyplot.show>
